# %% [markdown]
# <a href="https://colab.research.google.com/github/sergejhorvat/Tensorflow2.0_Udemy/blob/master/Building_an_Artificial_Neural_Network_in_TensorFlow_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
#   <img src="https://storage.googleapis.com/kaggle-datasets-images/2243/3791/9384af51de8baa77f6320901f53bd26b/dataset-cover.png" />
#   Image source: https://www.kaggle.com/
# </p>

# %% [markdown]
# ## Stage 1: Installing dependencies and setting up GPU environment

# %%
# !pip install tensorflow-gpu==2.0.0rc0
# Out:
# ...
#      |████████████████████████████████| 380.5MB 69kB/s
# ...
#      |████████████████████████████████| 4.3MB 24.5MB/s
# ...
#      |████████████████████████████████| 501kB 41.8MB/s
# ...
#   Found existing installation: tb-nightly 1.14.0a20190301
#     Uninstalling tb-nightly-1.14.0a20190301:
#       Successfully uninstalled tb-nightly-1.14.0a20190301
#   Found existing installation: tf-estimator-nightly 1.14.0.dev2019030115
#     Uninstalling tf-estimator-nightly-1.14.0.dev2019030115:
#       Successfully uninstalled tf-estimator-nightly-1.14.0.dev2019030115
#   Found existing installation: tensorflow-gpu 2.0.0a0
#     Uninstalling tensorflow-gpu-2.0.0a0:
#       Successfully uninstalled tensorflow-gpu-2.0.0a0
# ...

# %% [markdown]
# ## Stage 2: Import dependencies for the project

# %%
import numpy as np
import datetime
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# %%
tf.__version__
# Out:
# '2.0.0-rc0'

# %% [markdown]
# ## Stage 3: Dataset preprocessing

# %% [markdown]
# ### Loading the dataset

# %%
#Loading the Fashion Mnist dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
print("X training samples", X_train.shape)
print("y training samples", y_train.shape)
print("X testing samples", X_test.shape)
print("y testing samples", y_test.shape)
# Out:
# X training samples (60000, 28, 28)
# y training samples (60000,)
# X testing samples (10000, 28, 28)
# y testing samples (10000,)

# %% [markdown]
# ### Image normalization
#
# We devide each image in the training and testing dataset with the maxiumum number of pixels (255).
#
# In this way each pixel will be in the rainge [0, 1]. By normalizing imaes we are making sure that our model (ANN) trains faster.

# %%
X_train = X_train / 255.0

# %%
X_test = X_test / 255.0

# %% [markdown]
# ### Reshaping of the dataset
#
# Since we are using fully connected network, we reshape the training and testing subsets to be in the vector format.

# %%
#Since each image is 28x28, we simply use reshape the full dataset to [-1 (all elements), height * width]
X_train = X_train.reshape(-1, 28*28)
print("reshaped X_train: " , X_train.shape)
# Out:
# reshaped X_train:  (60000, 784)

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
#Reshape the testing subset in the same way
X_test = X_test.reshape(-1, 28*28)

# %% [markdown]
# ## Stage 4: Building an Artificial Neural network

# %% [markdown]
# ### Defining the model
#
# Simply define an object of the Sequential model.

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# ### Adding the first layer (Dense layer)
#
# Layer hyper-parameters:
# - number of units/neurons: 128
# - activation function: ReLU
# - input_shape: (784, )

# %%
model.add(tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784, )))

# %% [markdown]
# ### Adding a Dropout layer
#
# Dropout is a Regularization technique where we randomly set neurons in a layer to zero. In this way, while training those neurons won't be updated. Because some percentage of neurons won't be updated the whole training process is long and we have less chance for overfitting.

# %%
model.add(tf.keras.layers.Dropout(0.1))

# %% [markdown]
# ### **Add some more layers for Homework assignement to exced 88% accuracy**
#
# *   One Dense layer
# *   One Drouput layer

# %%
model.add(tf.keras.layers.Dense(units=64, activation='relu'))
model.add(tf.keras.layers.Dropout(0.1))

# %% [markdown]
# ### Adding the second layer (output layer)
#
# - units == number of classes (10 in the case of Fashion MNIST)
# - activation = 'softmax'

# %%
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

# %% [markdown]
# ### Compiling the model
#
# - Optimizer: Adam
# - Loss: Sparse softmax (categorical) crossentropy

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                650
# ...
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
model.fit(X_train, y_train, epochs=15)
# Out:
# Train on 60000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.5345 - sparse_categorical_accuracy: 0.8080
# Epoch 2/15
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.3969 - sparse_categorical_accuracy: 0.8543
# Epoch 3/15
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.3632 - sparse_categorical_accuracy: 0.8667
# Epoch 4/15
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.3414 - sparse_categorical_accuracy: 0.8734
# Epoch 5/15
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.3246 - sparse_categorical_accuracy: 0.8797
# Epoch 6/15
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.3103 - sparse_categorical_accuracy: 0.8845
# Epoch 7/15
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.2993 - sparse_categorical_accuracy: 0.8885
# Epoch 8/15
# ...

# %% [markdown]
# ### Model evaluation and prediction

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
print("Test accuracy: {}".format(test_accuracy))
# Out:
# Test accuracy: 0.8877999782562256

# %% [markdown]
# ## Stage 5 : Saving the model

# %% [markdown]
# ### Saving the architecture (topology) of the network

# %%
model_json = model.to_json()
with open("fashion_model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# ### Saving network weights

# %%
model.save_weights("fashion_model.h5")
